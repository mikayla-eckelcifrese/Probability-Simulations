# %%
import numpy as np

#import matplotlib as plt

from matplotlib import pyplot as plt

# %% [markdown]
# 1D Sine wave

# %%
x = np.arange(-500, 501, 1)

wavelength = 200

pi = 3.14159265

y = np.sin(2*pi*x/wavelength)

plt.plot(x,y)

plt.show()

# %% [markdown]
# 2D Sine mesh

# %%
# noinspection PyUnresolvedReferences
X, Y = np.meshgrid(x,x)


plt.set_cmap("gray")

wavelength = np.linspace(100, 500, 5)

amplitude = np.linspace(0.01, 1, 10)

# for i in range(5):
#     grating = np.sin(2*pi*X/wavelength[i])
#     plt.imshow(grating)
#     plt.show()

for i in range(5):
    wavelength = 200
    grating = amplitude[i]*np.sin(2*pi*X/wavelength + 500)
    plt.imshow(grating)
    plt.show()
